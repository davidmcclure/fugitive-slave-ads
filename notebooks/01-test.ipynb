# %%
from fugitive import Corpus

corpus = Corpus('../data/North Carolina/')

# %%
jj = corpus.count_pos('JJ')
# Out:
# ../data/North Carolina/NC Texts 1751-1792/RAS_1118-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1119-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1120-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1122-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1126-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1128-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1130-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1135-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1143-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1147-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1148-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1149-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1153-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1168-metadata.txt
# ../data/North Carolina/NC Texts 1751-1792/RAS_1169-metadata.txt
# ...

# %%
jj.most_common(100)
# Out:
# [('high', 1559),
#  ('above', 1380),
#  ('negro', 1051),
#  ('last', 933),
#  ('black', 860),
#  ('old', 836),
#  ('free', 609),
#  ('<', 541),
#  ('reasonable', 476),
#  ('white', 455),
#  ('yellow', 433),
#  ('dark', 422),
#  ('other', 388),
#  ('large', 381),
#  ('sic', 344),
#  ('small', 332),
#  ('good', 313),
#  ('likely', 293),
#  ('little', 245),
#  ('again.', 196),
#  ('probable', 194),
#  ('twenty-five', 183),
#  ('left', 183),
#  ('right', 176),
#  ('blue', 168),
#  ('him.', 149),
#  ('same', 145),
#  ('light', 145),
#  ('ten', 143),
#  ('short', 139),
#  ('bright', 138),
#  ('fellow', 136),
#  ('illegible', 131),
#  ('thick', 126),
#  ('common', 120),
#  ('such', 119),
#  ('first', 111),
#  ('upper', 103),
#  ('full', 102),
#  ('new', 102),
#  ('twenty', 99),
#  ('thirty', 99),
#  ('several', 97),
#  ('yellowish', 96),
#  ('low', 95),
#  ('artful', 92),
#  ('broad', 92),
#  ('great', 90),
#  ('few', 85),
#  ('tolerable', 82),
#  ('thin', 81),
#  ('[', 81),
# ...
